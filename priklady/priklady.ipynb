# %%
from random import shuffle, choice, random
from reportlab.pdfgen.canvas import Canvas 
from reportlab.lib.units import cm, inch
from reportlab.lib.pagesizes import A4
from reportlab.lib import colors
from pathlib import Path

dst_fld = Path("c:/tmp/priklady")
dst_file = "priklady.pdf"
dst_path = dst_fld / dst_file

# %%
operands = []
for i in range(3,10):
    for j in range(3,10):
        operands.append((i,j))

shuffle(operands)
operands.extend(operands[0:3]) # extra 3 pro zarovnani na 4 * 13

# %%
minus_results = list(range(-11,-1))
# shuffle(minus_minus_results)

# %%
priklady = []
toggle = True
for o in operands:
    oper_a, oper_b = o
    toggle = not toggle

    mul_result = oper_a * oper_b
    if mul_result < 30:
        minus_result = choice(range(-11,-0))
        minus_operand = mul_result - minus_result
        result = mul_result - minus_operand
        if toggle:
            priklad = f"({oper_a} x {oper_b}) - {minus_operand}   "
        else:
            priklad = f"- {minus_operand} + ({oper_a} x {oper_b}) "


    elif mul_result > 60:
        minus_operand = choice(range(21,50))
        result = mul_result - minus_operand
        if toggle:
            priklad = f"({oper_a} x {oper_b}) - {minus_operand}   "
        else:
            priklad = f"- {minus_operand} + ({oper_a} x {oper_b}) "    

    else:
        plus_operand = choice(range(21,40))
        result = mul_result + plus_operand
        if toggle:
            priklad = f"({oper_a} x {oper_b}) + {plus_operand}   "
        else:
            priklad = f"{plus_operand} + ({oper_a} x {oper_b})   "       

    print(f"{priklad}= {result}")
    priklady.append((priklad, result))
# Out:
# - 20 + (6 x 3) = -2
# (4 x 9) + 38   = 74
# - 30 + (5 x 5) = -5
# (5 x 9) + 23   = 68
# 38 + (9 x 5)   = 83
# (7 x 7) + 37   = 86
# 31 + (5 x 6)   = 61
# (6 x 4) - 32   = -8
# - 27 + (3 x 7) = -6
# (6 x 7) + 25   = 67
# 22 + (8 x 4)   = 54
# (6 x 5) + 26   = 56
# - 19 + (3 x 5) = -4
# (4 x 4) - 22   = -6
# - 30 + (4 x 6) = -6
# (8 x 3) - 31   = -7
# - 30 + (4 x 7) = -2
# (8 x 6) + 23   = 71
# - 24 + (8 x 9) = 48
# (8 x 5) + 39   = 79
# - 25 + (4 x 5) = -5
# (7 x 9) - 26   = 37
# 33 + (6 x 9)   = 87
# (6 x 6) + 24   = 60
# - 44 + (9 x 9) = 37
# (9 x 4) + 23   = 59
# 38 + (6 x 8)   = 86
# (4 x 8) + 38   = 70
# 38 + (7 x 5)   = 73
# (7 x 4) - 32   = -4
# - 21 + (9 x 7) = 42
# (9 x 8) - 31   = 41
# - 23 + (3 x 6) = -5
# (4 x 3) - 20   = -8
# 25 + (8 x 7)   = 81
# (8 x 8) - 49   = 15
# - 10 + (3 x 3) = -1
# (9 x 6) + 39   = 93
# - 21 + (5 x 3) = -6
# (3 x 4) - 19   = -7
# - 35 + (3 x 9) = -8
# (9 x 3) - 30   = -3
# 27 + (5 x 7)   = 62
# (5 x 8) + 23   = 63
# - 28 + (5 x 4) = -8
# (7 x 3) - 31   = -10
# - 26 + (3 x 8) = -2
# (7 x 8) + 30   = 86
# 35 + (7 x 6)   = 77
# (6 x 3) - 26   = -8
# 33 + (4 x 9)   = 69
# (5 x 5) - 31   = -6

# %%
canvas = Canvas(r"c:\tmp\priklady\priklady.pdf", pagesize=A4)

priklad_per_page = 13

v_position_start = 11 * inch
v_position_off = 0.8 * inch
v_position = v_position_start

canvas.setFont("Helvetica", 18)

counter = 1
for p in priklady:
    if counter > priklad_per_page:

        pgn = str(canvas.getPageNumber())
        canvas.setFont("Helvetica", 8)
        canvas.drawString(7*inch, 36, f"page: {pgn}")

        canvas.showPage()
        
        v_position_start = 11 * inch
        v_position_off = 0.8 * inch
        v_position = v_position_start
        
        canvas.setFont("Helvetica", 18)

        counter = 1

    txt = p[0]
    canvas.drawString(72, v_position, txt)
    canvas.drawString(180, v_position, "= ")

    canvas.setStrokeColor(colors.lightgrey) 
    canvas.line(220,v_position - 8 ,290,v_position - 8)

    v_position -= v_position_off

    counter += 1

pgn = str(canvas.getPageNumber())
canvas.setFont("Helvetica", 8)
canvas.drawString(7*inch, 36, f"page: {pgn}")
canvas.showPage()
canvas.setFont("Helvetica", 18)

counter = 1
v_position_start = 11 * inch
v_position_off = 0.8 * inch
v_position = v_position_start
h_possition = inch
for p in priklady:
    if counter > priklad_per_page:
        h_possition += inch
        v_position_start = 11 * inch
        v_position_off = 0.8 * inch
        v_position = v_position_start
        counter = 1
    txt = str(p[1])
    canvas.drawString(h_possition, v_position, txt)
    v_position -= v_position_off
    counter += 1


canvas.save()
